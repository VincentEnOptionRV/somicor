# %%
import sonification as snf

# %%
liste_pics = [144,135,212,440,45,843,555,220,2000]

# %%
tn = snf.freq_list_to_tinyNotation(liste_pics)
print(tn)
# Out:
# tinyNotation: 4/4 FFF4 C4 D4 A4 A4 a4 c'4 a'4 b''4

# %%
sound = snf.mus.converter.parse(tn)

# %%
sound.show()

# %%
sound.show('midi')
# Out:
#                 <div id="midiPlayerDiv250"></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer("#midiPlayerDiv250");
#                                mp.base64Load("...");
#                         });
#                 </script>
